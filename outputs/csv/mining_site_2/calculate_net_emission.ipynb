# %%
import pandas as pd
import glob

# Scenario options dictionary
scenario_options = {
    'redchris': ['no_cons','evenflow_cons', 'bau_redchrs', 'redchrs_AAC_90%', 'redchrs_AAC_80%', 'redchrs_AAC_70%', 'redchrs_AAC_60%', 'redchrs_AAC_50%', 'redchrs_AAC_40%', 'redchrs_AAC_30%', 'redchrs_AAC_20%', 'redchrs_AAC_10%' ],
    'goldenbear': ['no_cons', 'evenflow_cons', 'bau_gldbr', 'gldbr_AAC_90%', 'gldbr_AAC_80%', 'gldbr_AAC_70%', 'gldbr_AAC_60%', 'gldbr_AAC_50%', 'gldbr_AAC_40%', 'gldbr_AAC_30%', 'gldbr_AAC_20%', 'gldbr_AAC_10%'],
    'equitysilver': [ 'no_cons','evenflow_cons', 'bau_eqtslvr', 'eqtslvr_AAC_90%', 'eqtslvr_AAC_80%', 'eqtslvr_AAC_70%', 'eqtslvr_AAC_60%', 'eqtslvr_AAC_50%', 'eqtslvr_AAC_40%', 'eqtslvr_AAC_30%', 'eqtslvr_AAC_20%', 'eqtslvr_AAC_10%'],
    'test': ['no_cons', 'evenflow_cons', 'bau_redchrs']
}

case_study = ['redchris', 'goldenbear', 'equitysilver']
obj_mode = ['max_hv', 'min_ha', 'max_st', 'min_em']

# Loop through each case study
for case in case_study:
    for mode in obj_mode:
        for scenario_name in scenario_options[case]:
            # Build the file pattern dynamically
            file_pattern = f'{case}_{mode}_{scenario_name}_cbm_output_2.csv'
            files = glob.glob(file_pattern)
            
            # Dictionary to store results
            net_emission_sums = {}

            # Loop through each file
            for file_path in files:
                # Read the CSV file
                data = pd.read_csv(file_path)
                
                # Calculate the sum of the 'Net emission' column
                net_emission_sum = data['Net emission'].sum()
                
                # Store the result in the dictionary with the filename as the key
                net_emission_sums[file_path] = net_emission_sum

            # Print the results
            for file, total in net_emission_sums.items():
                print(f"Total Net emission for {file}: {total}")
# Out:
# Total Net emission for goldenbear_max_hv_no_cons_cbm_output_2.csv: -29189776.93915654
# Total Net emission for goldenbear_max_hv_evenflow_cons_cbm_output_2.csv: -6207187.211425678
# Total Net emission for goldenbear_max_hv_bau_gldbr_cbm_output_2.csv: -22431846.754658174
# Total Net emission for goldenbear_max_hv_gldbr_AAC_90%_cbm_output_2.csv: -20816108.755755942
# Total Net emission for goldenbear_max_hv_gldbr_AAC_80%_cbm_output_2.csv: -24435190.066874854
# Total Net emission for goldenbear_max_hv_gldbr_AAC_70%_cbm_output_2.csv: -27875150.26049271
# Total Net emission for goldenbear_max_hv_gldbr_AAC_60%_cbm_output_2.csv: -30827647.013554625
# Total Net emission for goldenbear_max_hv_gldbr_AAC_50%_cbm_output_2.csv: -33795281.84201903
# Total Net emission for goldenbear_max_hv_gldbr_AAC_40%_cbm_output_2.csv: -37203091.17930901
# Total Net emission for goldenbear_max_hv_gldbr_AAC_30%_cbm_output_2.csv: -40172516.83775847
# Total Net emission for goldenbear_max_hv_gldbr_AAC_20%_cbm_output_2.csv: -43335597.25980165
# Total Net emission for goldenbear_max_hv_gldbr_AAC_10%_cbm_output_2.csv: -46257710.95081139
# Total Net emission for goldenbear_min_ha_no_cons_cbm_output_2.csv: -49427321.687680066
# Total Net emission for goldenbear_min_ha_evenflow_cons_cbm_output_2.csv: -49427321.687680066
# Total Net emission for goldenbear_min_ha_bau_gldbr_cbm_output_2.csv: -30666617.03353386
# Total Net emission for goldenbear_min_ha_gldbr_AAC_90%_cbm_output_2.csv: -32934008.85661996
# Total Net emission for goldenbear_min_ha_gldbr_AAC_80%_cbm_output_2.csv: -35234780.169505574
# Total Net emission for goldenbear_min_ha_gldbr_AAC_70%_cbm_output_2.csv: -37362830.438994355
# Total Net emission for goldenbear_min_ha_gldbr_AAC_60%_cbm_output_2.csv: -39353227.93747746
# Total Net emission for goldenbear_min_ha_gldbr_AAC_50%_cbm_output_2.csv: -41384955.597183906
# Total Net emission for goldenbear_min_ha_gldbr_AAC_40%_cbm_output_2.csv: -43112708.095089994
# Total Net emission for goldenbear_min_ha_gldbr_AAC_30%_cbm_output_2.csv: -44772679.13494008
# Total Net emission for goldenbear_min_ha_gldbr_AAC_20%_cbm_output_2.csv: -46464434.58187243
# Total Net emission for goldenbear_min_ha_gldbr_AAC_10%_cbm_output_2.csv: -48017286.35753632
# Total Net emission for goldenbear_max_st_no_cons_cbm_output_2.csv: -25461586.222180314
# Total Net emission for goldenbear_max_st_evenflow_cons_cbm_output_2.csv: -47427124.91602865
# Total Net emission for goldenbear_max_st_bau_gldbr_cbm_output_2.csv: -29703226.863862857
# Total Net emission for goldenbear_max_st_gldbr_AAC_90%_cbm_output_2.csv: -31862586.421735607
# Total Net emission for goldenbear_max_st_gldbr_AAC_80%_cbm_output_2.csv: -33979373.97688876
# Total Net emission for goldenbear_max_st_gldbr_AAC_70%_cbm_output_2.csv: -35983123.11962444
# Total Net emission for goldenbear_max_st_gldbr_AAC_60%_cbm_output_2.csv: -38092738.042020574
# Total Net emission for goldenbear_max_st_gldbr_AAC_50%_cbm_output_2.csv: -40163420.77247813
# Total Net emission for goldenbear_max_st_gldbr_AAC_40%_cbm_output_2.csv: -42316628.016321056
# Total Net emission for goldenbear_max_st_gldbr_AAC_30%_cbm_output_2.csv: -44282373.21534899
# Total Net emission for goldenbear_max_st_gldbr_AAC_20%_cbm_output_2.csv: -46158178.29176428
# Total Net emission for goldenbear_max_st_gldbr_AAC_10%_cbm_output_2.csv: -47882893.27932464
# Total Net emission for goldenbear_min_em_no_cons_cbm_output_2.csv: -46089867.53861271
# Total Net emission for goldenbear_min_em_evenflow_cons_cbm_output_2.csv: -49156432.64804561
# Total Net emission for goldenbear_min_em_bau_gldbr_cbm_output_2.csv: -33239922.16331606
# Total Net emission for goldenbear_min_em_gldbr_AAC_90%_cbm_output_2.csv: -35415830.69538684
# Total Net emission for goldenbear_min_em_gldbr_AAC_80%_cbm_output_2.csv: -37514129.614480205
# Total Net emission for goldenbear_min_em_gldbr_AAC_70%_cbm_output_2.csv: -39494983.06312865
# Total Net emission for goldenbear_min_em_gldbr_AAC_60%_cbm_output_2.csv: -41196986.38111655
# Total Net emission for goldenbear_min_em_gldbr_AAC_50%_cbm_output_2.csv: -43010860.276105195
# Total Net emission for goldenbear_min_em_gldbr_AAC_40%_cbm_output_2.csv: -44663712.33861428
# Total Net emission for goldenbear_min_em_gldbr_AAC_30%_cbm_output_2.csv: -46281647.31697498
# Total Net emission for goldenbear_min_em_gldbr_AAC_20%_cbm_output_2.csv: -47578947.39935211
# Total Net emission for goldenbear_min_em_gldbr_AAC_10%_cbm_output_2.csv: -48617302.777962424
