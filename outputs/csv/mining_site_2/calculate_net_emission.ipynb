# %%
import pandas as pd
import glob

# Scenario options dictionary
scenario_options = {
    'mining_site_1': ['no_cons','evenflow_cons', 'bau_ms1', 'ms1_AAC_90%', 'ms1_AAC_80%', 'ms1_AAC_70%', 'ms1_AAC_60%', 'ms1_AAC_50%', 'ms1_AAC_40%', 'ms1_AAC_30%', 'ms1_AAC_20%', 'ms1_AAC_10%' ],
    'mining_site_2': ['no_cons','evenflow_cons', 'bau_ms2', 'ms2_AAC_90%', 'ms2_AAC_80%', 'ms2_AAC_70%', 'ms2_AAC_60%', 'ms2_AAC_50%', 'ms2_AAC_40%', 'ms2_AAC_30%', 'ms2_AAC_20%', 'ms2_AAC_10%' ],
    'mining_site_3': ['no_cons','evenflow_cons', 'bau_ms3', 'ms3_AAC_90%', 'ms3_AAC_80%', 'ms3_AAC_70%', 'ms3_AAC_60%', 'ms3_AAC_50%', 'ms3_AAC_40%', 'ms3_AAC_30%', 'ms3_AAC_20%', 'ms3_AAC_10%' ]
}

case_study = ['mining_site_1', 'mining_site_2', 'mining_site_3']
obj_mode = ['max_hv', 'min_ha', 'max_st', 'min_em']

# Loop through each case study
for case in case_study:
    for mode in obj_mode:
        for scenario_name in scenario_options[case]:
            # Build the file pattern dynamically
            file_pattern = f'{case}_{mode}_{scenario_name}_cbm_output_2.csv'
            files = glob.glob(file_pattern)
            
            # Dictionary to store results
            net_emission_sums = {}

            # Loop through each file
            for file_path in files:
                # Read the CSV file
                data = pd.read_csv(file_path)
                
                # Calculate the sum of the 'Net emission' column
                net_emission_sum = data['Net emission'].sum()
                
                # Store the result in the dictionary with the filename as the key
                net_emission_sums[file_path] = net_emission_sum

            # Print the results
            for file, total in net_emission_sums.items():
                print(f"Total Net emission for {file}: {total}")
# Out:
# Total Net emission for mining_site_2_max_hv_no_cons_cbm_output_2.csv: -29189776.93915654
# Total Net emission for mining_site_2_max_hv_evenflow_cons_cbm_output_2.csv: -6207187.211425678
# Total Net emission for mining_site_2_max_hv_bau_ms2_cbm_output_2.csv: -22431846.754658174
# Total Net emission for mining_site_2_max_hv_ms2_AAC_90%_cbm_output_2.csv: -20816108.755755942
# Total Net emission for mining_site_2_max_hv_ms2_AAC_80%_cbm_output_2.csv: -24435190.066874854
# Total Net emission for mining_site_2_max_hv_ms2_AAC_70%_cbm_output_2.csv: -27875150.26049271
# Total Net emission for mining_site_2_max_hv_ms2_AAC_60%_cbm_output_2.csv: -30827647.013554625
# Total Net emission for mining_site_2_max_hv_ms2_AAC_50%_cbm_output_2.csv: -33795281.84201903
# Total Net emission for mining_site_2_max_hv_ms2_AAC_40%_cbm_output_2.csv: -37203091.17930901
# Total Net emission for mining_site_2_max_hv_ms2_AAC_30%_cbm_output_2.csv: -40172516.83775847
# Total Net emission for mining_site_2_max_hv_ms2_AAC_20%_cbm_output_2.csv: -43335597.25980165
# Total Net emission for mining_site_2_max_hv_ms2_AAC_10%_cbm_output_2.csv: -46257710.95081139
# Total Net emission for mining_site_2_min_ha_no_cons_cbm_output_2.csv: -49427321.687680066
# Total Net emission for mining_site_2_min_ha_evenflow_cons_cbm_output_2.csv: -49427321.687680066
# Total Net emission for mining_site_2_min_ha_bau_ms2_cbm_output_2.csv: -30666617.03353386
# Total Net emission for mining_site_2_min_ha_ms2_AAC_90%_cbm_output_2.csv: -32934008.85661996
# Total Net emission for mining_site_2_min_ha_ms2_AAC_80%_cbm_output_2.csv: -35234780.169505574
# Total Net emission for mining_site_2_min_ha_ms2_AAC_70%_cbm_output_2.csv: -37362830.438994355
# Total Net emission for mining_site_2_min_ha_ms2_AAC_60%_cbm_output_2.csv: -39353227.93747746
# Total Net emission for mining_site_2_min_ha_ms2_AAC_50%_cbm_output_2.csv: -41384955.597183906
# Total Net emission for mining_site_2_min_ha_ms2_AAC_40%_cbm_output_2.csv: -43112708.095089994
# Total Net emission for mining_site_2_min_ha_ms2_AAC_30%_cbm_output_2.csv: -44772679.13494008
# Total Net emission for mining_site_2_min_ha_ms2_AAC_20%_cbm_output_2.csv: -46464434.58187243
# Total Net emission for mining_site_2_min_ha_ms2_AAC_10%_cbm_output_2.csv: -48017286.35753632
# Total Net emission for mining_site_2_max_st_no_cons_cbm_output_2.csv: -48438209.12866604
# Total Net emission for mining_site_2_max_st_evenflow_cons_cbm_output_2.csv: -49427321.687680066
# Total Net emission for mining_site_2_max_st_bau_ms2_cbm_output_2.csv: -27691925.353361275
# Total Net emission for mining_site_2_max_st_ms2_AAC_90%_cbm_output_2.csv: -34995663.51912935
# Total Net emission for mining_site_2_max_st_ms2_AAC_80%_cbm_output_2.csv: -37138002.52619889
# Total Net emission for mining_site_2_max_st_ms2_AAC_70%_cbm_output_2.csv: -39157846.72909777
# Total Net emission for mining_site_2_max_st_ms2_AAC_60%_cbm_output_2.csv: -41090638.29926648
# Total Net emission for mining_site_2_max_st_ms2_AAC_50%_cbm_output_2.csv: -42923815.490125835
# Total Net emission for mining_site_2_max_st_ms2_AAC_40%_cbm_output_2.csv: -44598486.904481806
# Total Net emission for mining_site_2_max_st_ms2_AAC_30%_cbm_output_2.csv: -46225607.2615423
# Total Net emission for mining_site_2_max_st_ms2_AAC_20%_cbm_output_2.csv: -47539676.116311386
# Total Net emission for mining_site_2_max_st_ms2_AAC_10%_cbm_output_2.csv: -48576478.51893555
# Total Net emission for mining_site_2_min_em_no_cons_cbm_output_2.csv: -49347182.80087994
# Total Net emission for mining_site_2_min_em_evenflow_cons_cbm_output_2.csv: -49406956.10950351
# Total Net emission for mining_site_2_min_em_bau_ms2_cbm_output_2.csv: -31101737.200817674
# Total Net emission for mining_site_2_min_em_ms2_AAC_90%_cbm_output_2.csv: -35592895.63448915
# Total Net emission for mining_site_2_min_em_ms2_AAC_80%_cbm_output_2.csv: -37676137.366995715
# Total Net emission for mining_site_2_min_em_ms2_AAC_70%_cbm_output_2.csv: -39670890.3140534
# Total Net emission for mining_site_2_min_em_ms2_AAC_60%_cbm_output_2.csv: -41552426.36216725
# Total Net emission for mining_site_2_min_em_ms2_AAC_50%_cbm_output_2.csv: -43331349.40842358
# Total Net emission for mining_site_2_min_em_ms2_AAC_40%_cbm_output_2.csv: -44975939.73816747
# Total Net emission for mining_site_2_min_em_ms2_AAC_30%_cbm_output_2.csv: -46450268.08669675
# Total Net emission for mining_site_2_min_em_ms2_AAC_20%_cbm_output_2.csv: -47680015.475822866
# Total Net emission for mining_site_2_min_em_ms2_AAC_10%_cbm_output_2.csv: -48649924.74091814
