# %%
import pandas as pd
import glob

# Scenario options dictionary
scenario_options = {
    'redchris': ['no_cons','evenflow_cons', 'bau_redchrs', 'redchrs_AAC_90%', 'redchrs_AAC_80%', 'redchrs_AAC_70%', 'redchrs_AAC_60%', 'redchrs_AAC_50%', 'redchrs_AAC_40%', 'redchrs_AAC_30%', 'redchrs_AAC_20%', 'redchrs_AAC_10%' ],
    'goldenbear': ['no_cons', 'evenflow_cons', 'bau_gldbr', 'gldbr_AAC_90%', 'gldbr_AAC_80%', 'gldbr_AAC_70%', 'gldbr_AAC_60%', 'gldbr_AAC_50%', 'gldbr_AAC_40%', 'gldbr_AAC_30%', 'gldbr_AAC_20%', 'gldbr_AAC_10%'],
    'equitysilver': [ 'no_cons','evenflow_cons', 'bau_eqtslvr', 'eqtslvr_AAC_90%', 'eqtslvr_AAC_80%', 'eqtslvr_AAC_70%', 'eqtslvr_AAC_60%', 'eqtslvr_AAC_50%', 'eqtslvr_AAC_40%', 'eqtslvr_AAC_30%', 'eqtslvr_AAC_20%', 'eqtslvr_AAC_10%'],
    'test': ['no_cons', 'evenflow_cons', 'bau_redchrs']
}

case_study = ['redchris', 'goldenbear', 'equitysilver']
obj_mode = ['max_hv', 'min_ha', 'max_st', 'min_em']

# Loop through each case study
for case in case_study:
    for mode in obj_mode:
        for scenario_name in scenario_options[case]:
            # Build the file pattern dynamically
            file_pattern = f'{case}_{mode}_{scenario_name}_cbm_output_2.csv'
            files = glob.glob(file_pattern)
            
            # Dictionary to store results
            net_emission_sums = {}

            # Loop through each file
            for file_path in files:
                # Read the CSV file
                data = pd.read_csv(file_path)
                
                # Calculate the sum of the 'Net emission' column
                net_emission_sum = data['Net emission'].sum()
                
                # Store the result in the dictionary with the filename as the key
                net_emission_sums[file_path] = net_emission_sum

            # Print the results
            for file, total in net_emission_sums.items():
                print(f"Total Net emission for {file}: {total}")
# Out:
# Total Net emission for redchris_max_hv_no_cons_cbm_output_2.csv: -47748762.08435674
# Total Net emission for redchris_max_hv_evenflow_cons_cbm_output_2.csv: -20553822.249916766
# Total Net emission for redchris_max_hv_bau_redchrs_cbm_output_2.csv: -46083355.39637767
# Total Net emission for redchris_max_hv_redchrs_AAC_90%_cbm_output_2.csv: -50234031.335655786
# Total Net emission for redchris_max_hv_redchrs_AAC_80%_cbm_output_2.csv: -52652856.689681344
# Total Net emission for redchris_max_hv_redchrs_AAC_70%_cbm_output_2.csv: -56559028.3513204
# Total Net emission for redchris_max_hv_redchrs_AAC_60%_cbm_output_2.csv: -61565532.21264179
# Total Net emission for redchris_max_hv_redchrs_AAC_50%_cbm_output_2.csv: -64192028.35436059
# Total Net emission for redchris_max_hv_redchrs_AAC_40%_cbm_output_2.csv: -68328829.59417821
# Total Net emission for redchris_max_hv_redchrs_AAC_30%_cbm_output_2.csv: -71715541.98664466
# Total Net emission for redchris_max_hv_redchrs_AAC_20%_cbm_output_2.csv: -76112747.39804064
# Total Net emission for redchris_max_hv_redchrs_AAC_10%_cbm_output_2.csv: -78934797.7320566
# Total Net emission for redchris_min_ha_no_cons_cbm_output_2.csv: -81552275.62061478
# Total Net emission for redchris_min_ha_evenflow_cons_cbm_output_2.csv: -81552275.62061478
# Total Net emission for redchris_min_ha_bau_redchrs_cbm_output_2.csv: -60129917.95418958
# Total Net emission for redchris_min_ha_redchrs_AAC_90%_cbm_output_2.csv: -62486615.16274758
# Total Net emission for redchris_min_ha_redchrs_AAC_80%_cbm_output_2.csv: -64832416.03318585
# Total Net emission for redchris_min_ha_redchrs_AAC_70%_cbm_output_2.csv: -67151265.97270414
# Total Net emission for redchris_min_ha_redchrs_AAC_60%_cbm_output_2.csv: -69383983.86332767
# Total Net emission for redchris_min_ha_redchrs_AAC_50%_cbm_output_2.csv: -71593454.89161646
# Total Net emission for redchris_min_ha_redchrs_AAC_40%_cbm_output_2.csv: -73778154.66428365
# Total Net emission for redchris_min_ha_redchrs_AAC_30%_cbm_output_2.csv: -75962420.47366019
# Total Net emission for redchris_min_ha_redchrs_AAC_20%_cbm_output_2.csv: -77708010.31198609
# Total Net emission for redchris_min_ha_redchrs_AAC_10%_cbm_output_2.csv: -79628597.58415417
# Total Net emission for redchris_max_st_no_cons_cbm_output_2.csv: -39343713.161154926
# Total Net emission for redchris_max_st_evenflow_cons_cbm_output_2.csv: -69665405.27066658
# Total Net emission for redchris_max_st_bau_redchrs_cbm_output_2.csv: -57934898.02830422
# Total Net emission for redchris_max_st_redchrs_AAC_90%_cbm_output_2.csv: -60302708.38071118
# Total Net emission for redchris_max_st_redchrs_AAC_80%_cbm_output_2.csv: -62500532.70812171
# Total Net emission for redchris_max_st_redchrs_AAC_70%_cbm_output_2.csv: -64803655.62836335
# Total Net emission for redchris_max_st_redchrs_AAC_60%_cbm_output_2.csv: -67209106.06164517
# Total Net emission for redchris_max_st_redchrs_AAC_50%_cbm_output_2.csv: -69524504.54666437
# Total Net emission for redchris_max_st_redchrs_AAC_40%_cbm_output_2.csv: -71850188.38200085
# Total Net emission for redchris_max_st_redchrs_AAC_30%_cbm_output_2.csv: -74238669.06699364
# Total Net emission for redchris_max_st_redchrs_AAC_20%_cbm_output_2.csv: -76694146.34184597
# Total Net emission for redchris_max_st_redchrs_AAC_10%_cbm_output_2.csv: -79267064.97247855
# Total Net emission for redchris_min_em_no_cons_cbm_output_2.csv: -67795804.4413944
# Total Net emission for redchris_min_em_evenflow_cons_cbm_output_2.csv: -81479064.86173363
# Total Net emission for redchris_min_em_bau_redchrs_cbm_output_2.csv: -61796778.89949578
# Total Net emission for redchris_min_em_redchrs_AAC_90%_cbm_output_2.csv: -64047320.56003565
# Total Net emission for redchris_min_em_redchrs_AAC_80%_cbm_output_2.csv: -66281064.10107592
# Total Net emission for redchris_min_em_redchrs_AAC_70%_cbm_output_2.csv: -68400960.85963334
# Total Net emission for redchris_min_em_redchrs_AAC_60%_cbm_output_2.csv: -70675677.3659686
# Total Net emission for redchris_min_em_redchrs_AAC_50%_cbm_output_2.csv: -72760412.50272922
# Total Net emission for redchris_min_em_redchrs_AAC_40%_cbm_output_2.csv: -74604781.5940874
# Total Net emission for redchris_min_em_redchrs_AAC_30%_cbm_output_2.csv: -76729441.4391397
# Total Net emission for redchris_min_em_redchrs_AAC_20%_cbm_output_2.csv: -78730608.63268594
# Total Net emission for redchris_min_em_redchrs_AAC_10%_cbm_output_2.csv: -80475093.21642166
