# %%
import pandas as pd
import glob

# Scenario options dictionary
scenario_options = {
    'mining_site_1': ['no_cons','evenflow_cons', 'bau_ms1', 'ms1_AAC_90%', 'ms1_AAC_80%', 'ms1_AAC_70%', 'ms1_AAC_60%', 'ms1_AAC_50%', 'ms1_AAC_40%', 'ms1_AAC_30%', 'ms1_AAC_20%', 'ms1_AAC_10%' ],
    'mining_site_2': ['no_cons','evenflow_cons', 'bau_ms2', 'ms2_AAC_90%', 'ms2_AAC_80%', 'ms2_AAC_70%', 'ms2_AAC_60%', 'ms2_AAC_50%', 'ms2_AAC_40%', 'ms2_AAC_30%', 'ms2_AAC_20%', 'ms2_AAC_10%' ],
    'mining_site_3': ['no_cons','evenflow_cons', 'bau_ms3', 'ms3_AAC_90%', 'ms3_AAC_80%', 'ms3_AAC_70%', 'ms3_AAC_60%', 'ms3_AAC_50%', 'ms3_AAC_40%', 'ms3_AAC_30%', 'ms3_AAC_20%', 'ms3_AAC_10%' ]
}

case_study = ['mining_site_1', 'mining_site_2', 'mining_site_3']
obj_mode = ['max_hv', 'min_ha', 'max_st', 'min_em']

# Loop through each case study
for case in case_study:
    for mode in obj_mode:
        for scenario_name in scenario_options[case]:
            # Build the file pattern dynamically
            file_pattern = f'{case}_{mode}_{scenario_name}_cbm_output_2.csv'
            files = glob.glob(file_pattern)
            
            # Dictionary to store results
            net_emission_sums = {}

            # Loop through each file
            for file_path in files:
                # Read the CSV file
                data = pd.read_csv(file_path)
                
                # Calculate the sum of the 'Net emission' column
                net_emission_sum = data['Net emission'].sum()
                
                # Store the result in the dictionary with the filename as the key
                net_emission_sums[file_path] = net_emission_sum

            # Print the results
            for file, total in net_emission_sums.items():
                print(f"Total Net emission for {file}: {total}")
# Out:
# Total Net emission for mining_site_3_max_hv_no_cons_cbm_output_2.csv: -47748762.08435674
# Total Net emission for mining_site_3_max_hv_evenflow_cons_cbm_output_2.csv: -20553822.249916766
# Total Net emission for mining_site_3_max_hv_bau_ms3_cbm_output_2.csv: -46083355.39637767
# Total Net emission for mining_site_3_max_hv_ms3_AAC_90%_cbm_output_2.csv: -50234031.335655786
# Total Net emission for mining_site_3_max_hv_ms3_AAC_80%_cbm_output_2.csv: -52652856.689681344
# Total Net emission for mining_site_3_max_hv_ms3_AAC_70%_cbm_output_2.csv: -56559028.3513204
# Total Net emission for mining_site_3_max_hv_ms3_AAC_60%_cbm_output_2.csv: -61565532.21264179
# Total Net emission for mining_site_3_max_hv_ms3_AAC_50%_cbm_output_2.csv: -64192028.35436059
# Total Net emission for mining_site_3_max_hv_ms3_AAC_40%_cbm_output_2.csv: -68328829.59417821
# Total Net emission for mining_site_3_max_hv_ms3_AAC_30%_cbm_output_2.csv: -71715541.98664466
# Total Net emission for mining_site_3_max_hv_ms3_AAC_20%_cbm_output_2.csv: -76112747.39804064
# Total Net emission for mining_site_3_max_hv_ms3_AAC_10%_cbm_output_2.csv: -78934797.7320566
# Total Net emission for mining_site_3_min_ha_no_cons_cbm_output_2.csv: -81552275.62061478
# Total Net emission for mining_site_3_min_ha_evenflow_cons_cbm_output_2.csv: -81552275.62061478
# Total Net emission for mining_site_3_min_ha_bau_ms3_cbm_output_2.csv: -60129917.95418958
# Total Net emission for mining_site_3_min_ha_ms3_AAC_90%_cbm_output_2.csv: -62486615.16274758
# Total Net emission for mining_site_3_min_ha_ms3_AAC_80%_cbm_output_2.csv: -64832416.03318585
# Total Net emission for mining_site_3_min_ha_ms3_AAC_70%_cbm_output_2.csv: -67151265.97270414
# Total Net emission for mining_site_3_min_ha_ms3_AAC_60%_cbm_output_2.csv: -69383983.86332767
# Total Net emission for mining_site_3_min_ha_ms3_AAC_50%_cbm_output_2.csv: -71593454.89161646
# Total Net emission for mining_site_3_min_ha_ms3_AAC_40%_cbm_output_2.csv: -73778154.66428365
# Total Net emission for mining_site_3_min_ha_ms3_AAC_30%_cbm_output_2.csv: -75962420.47366019
# Total Net emission for mining_site_3_min_ha_ms3_AAC_20%_cbm_output_2.csv: -77708010.31198609
# Total Net emission for mining_site_3_min_ha_ms3_AAC_10%_cbm_output_2.csv: -79628597.58415417
# Total Net emission for mining_site_3_max_st_no_cons_cbm_output_2.csv: -79936234.50687195
# Total Net emission for mining_site_3_max_st_evenflow_cons_cbm_output_2.csv: -81552275.62061478
# Total Net emission for mining_site_3_max_st_bau_ms3_cbm_output_2.csv: -54944905.86415657
# Total Net emission for mining_site_3_max_st_ms3_AAC_90%_cbm_output_2.csv: -63710618.46071899
# Total Net emission for mining_site_3_max_st_ms3_AAC_80%_cbm_output_2.csv: -66055037.71494803
# Total Net emission for mining_site_3_max_st_ms3_AAC_70%_cbm_output_2.csv: -68411836.26896507
# Total Net emission for mining_site_3_max_st_ms3_AAC_60%_cbm_output_2.csv: -70656314.85394056
# Total Net emission for mining_site_3_max_st_ms3_AAC_50%_cbm_output_2.csv: -72753863.8050112
# Total Net emission for mining_site_3_max_st_ms3_AAC_40%_cbm_output_2.csv: -74813593.25792983
# Total Net emission for mining_site_3_max_st_ms3_AAC_30%_cbm_output_2.csv: -76809883.06822847
# Total Net emission for mining_site_3_max_st_ms3_AAC_20%_cbm_output_2.csv: -78787054.92578813
# Total Net emission for mining_site_3_max_st_ms3_AAC_10%_cbm_output_2.csv: -80471375.73658842
# Total Net emission for mining_site_3_min_em_no_cons_cbm_output_2.csv: -81372414.76524797
# Total Net emission for mining_site_3_min_em_evenflow_cons_cbm_output_2.csv: -81523017.28004785
# Total Net emission for mining_site_3_min_em_bau_ms3_cbm_output_2.csv: -59101238.864536084
# Total Net emission for mining_site_3_min_em_ms3_AAC_90%_cbm_output_2.csv: -64602517.280442305
# Total Net emission for mining_site_3_min_em_ms3_AAC_80%_cbm_output_2.csv: -66803615.22158845
# Total Net emission for mining_site_3_min_em_ms3_AAC_70%_cbm_output_2.csv: -68914305.77710064
# Total Net emission for mining_site_3_min_em_ms3_AAC_60%_cbm_output_2.csv: -70959314.10068241
# Total Net emission for mining_site_3_min_em_ms3_AAC_50%_cbm_output_2.csv: -72963909.04354937
# Total Net emission for mining_site_3_min_em_ms3_AAC_40%_cbm_output_2.csv: -75040719.13342783
# Total Net emission for mining_site_3_min_em_ms3_AAC_30%_cbm_output_2.csv: -77005884.81301197
# Total Net emission for mining_site_3_min_em_ms3_AAC_20%_cbm_output_2.csv: -78896293.9320053
# Total Net emission for mining_site_3_min_em_ms3_AAC_10%_cbm_output_2.csv: -80492010.99551137
